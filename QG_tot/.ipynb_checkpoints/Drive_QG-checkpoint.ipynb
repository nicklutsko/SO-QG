# %% [markdown]
# ## Beta test functionality for potential object oriented QG system.

# %% [markdown]
# #### This notebook / package provides an object oriented version of the 2d QG spectral model:
#
# available properties of each model:
#
#          Model grid size:
#
#         self.N=N
#         self.N2=N2
#         self.x = np.linspace( 0, 2. * np.pi * Lx, N )
#         self.y = np.linspace( 0, 2. * np.pi * Ly, N2 ) #domain size
#         self.ll = np.fft.fftfreq( N, Ly / float(N2) )
#         self.kk = np.fft.rfftfreq( N2, Lx / float(N) )
#
#         self.nu = .01 * (self.x[1] - self.x[0]) ** 4 #viscous dissipation
#         self.km = 1. / 5.4 #surface friction, corresponds to 25 days in JH
#         self.beta = 0.072 #beta in JH
#         self.dt = dt #time step
#         self.robert_coefficient = robert_coefficient
#         self.U = 1. #Maximum upper level wind speed
#         #Running EKE spectrum
#         self.ta = 100 #How often to calculate spectra
#         self.lim = 1 #when to start calculating spectra
#
#
#         #Spectral arrays, only need 3 time-steps
#         self.psic_1 = np.zeros( ( ( 3, N2, N // 2 + 1 ) ) ).astype( complex )
#         self.psic_2 = np.zeros( ( ( 3, N2, N // 2 + 1  ) ) ).astype( complex )
#         self.qc_1 = np.zeros( ( ( 3, N2, N // 2 + 1  ) ) ).astype( complex )
#         self.qc_2 = np.zeros( ( ( 3, N2, N // 2 + 1  ) ) ).astype( complex )
#         self.f0 = 40.
#         self.first_step = True
#         self.t=0
#         self.count=0
#         self.opt=3
#
#         #Topography -- Gaussian mountain
#         self.h_tm = 0.3 #h_max / H_2 (depth of lower layer)
#         self.f0 = 40.
#         self.xm = max( self.x )
#         self.ym = max( self.y )
#         self.h_halfx = self.xm / 4. #E-folding length in x-direction
#         self.h_halfy = self.ym / 4. #E-folding length in y-direction
#         self.h = self.h_tm * np.exp( -( (self.x[np.newaxis, :] - self.xm / 2.)  / self.h_halfx ) ** 2 - ( ( self.y[:, np.newaxis] - self.ym / 2.) / self.h_halfy ) ** 2 )
#         #Background PV
#         self.Q_1 = np.zeros( ( self.N2, self.N ) )
#         self.Q_1[:, :] = (self.beta + self.U / 2.) * self.y[:, np.newaxis]
#         self.Q_2 = (self.beta - self.U / 2.) * self.y[:, np.newaxis] + self.f0 * self.h
#
#         self.Q_1c = np.fft.rfft2( self.Q_1)
#         self.Q_2c = np.fft.rfft2( self.Q_2)

# %%
from QG.io import NetCDFWriter
from QG.model import QG2D_Model
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Instantiate a QG Model & Time Step It.
#
# This will save every step to a netcdf file

# %%
N1 = 64
N2 = 64
dt = 0.005

mod1 = QG2D_Model(N1,N2,dt,topo=True) #instantiates the model
mod1.random_init()  #randomly initiates the model.

print('Saving output at time: {}'.format(mod1.t))
mod1.integrate()
ModSaver = NetCDFWriter(mod1, 'New_Initiialize.nc')

#how many time steps to save: 
TS = 200  #BE CAREFUL THIS SAVES EVERY TIME STEP AND CAN GET BIG FAST.
for ii in range(0,TS):
    mod1.integrate()
    ModSaver.save()
ModSaver.close()
# Out:
# starting from scratch
# Saving output at time: 0
# /Volumes/HotSlop/QG_tot/QG/model.py:112: RuntimeWarning: divide by zero encountered in true_divide
#   psi_bt = -(self.qc_1[2] + self.qc_2[2]) / (self.ll[:, np.newaxis] ** 2 + self.kk[np.newaxis, :] ** 2) / 2.  # (psi_1 + psi_2)/2
# /Volumes/HotSlop/QG_tot/QG/model.py:112: RuntimeWarning: invalid value encountered in true_divide
#   psi_bt = -(self.qc_1[2] + self.qc_2[2]) / (self.ll[:, np.newaxis] ** 2 + self.kk[np.newaxis, :] ** 2) / 2.  # (psi_1 + psi_2)/2
# /Volumes/HotSlop/QG_tot/QG/model.py:118: RuntimeWarning: invalid value encountered in true_divide
#   psi_bt = -(self.qc_1[1] + self.qc_2[1]) / (self.ll[:, np.newaxis] ** 2 + self.kk[np.newaxis, :] ** 2) / 2.  # (psi_1 + psi_2)/2
# /Volumes/HotSlop/QG_tot/QG/model.py:118: RuntimeWarning: divide by zero encountered in true_divide
#   psi_bt = -(self.qc_1[1] + self.qc_2[1]) / (self.ll[:, np.newaxis] ** 2 + self.kk[np.newaxis, :] ** 2) / 2.  # (psi_1 + psi_2)/2

# %% [markdown]
# ## Function to Save 'Snap Shots':
#
# This function allows you to run and save every X steps

# %%
N1 = 64
N2 = 64
dt = 0.005

mod1 = QG2D_Model(N1,N2,dt,topo=True)
mod1.random_init()
print('First Step?:',mod1.first_step)
mod1.integrate()
print('First Step?:',mod1.first_step)
# Out:
# starting from scratch
# First Step?: True
# First Step?: False

# %%
N1 = 64
N2 = 64
dt = 0.005
mod1 = QG2D_Model(N1,N2,dt,topo=True)
mod1.random_init()
mod1.lim=20000 #spin up time.

mult1 = 70000 #total run time
mult2 = 100 #output save interval

saver = NetCDFWriter(mod1, 'SaveSnapShots.nc')
second = mod1.dt  #remember dt 
run_time = mult1 * second
output_interval = mult2 * second

#eventually put this in the back end? 
sk = np.zeros( ( ( mult1 // mult2, mod1.N2, mod1.N // 2 + 1) ) )
tak = np.zeros( ( ( mult1 // mult2, mod1.N2, mod1.N // 2 + 1) ) )
tkk = np.zeros( ( ( mult1 // mult2, mod1.N2, mod1.N // 2 + 1) ) )
tak = np.zeros( ( ( mult1 // mult2, mod1.N2, mod1.N // 2 + 1) ) )
fk = np.zeros( ( ( mult1 // mult2, mod1.N2, mod1.N // 2 + 1) ) )
vk = np.zeros( ( ( mult1 // mult2, mod1.N2, mod1.N // 2 + 1) ) )
ek = np.zeros( ( ( mult1 // mult2, mod1.N2, mod1.N // 2 + 1) ) )

print('spin up model')
for ii in range(0,mod1.lim):
    mod1.integrate()
print('..spun up.. ..saving in steps..')

print(mod1.t)
mod1.t=0 #this is hacky... fix it ... maybe use 'self.random_init()' to spin up the model too, then reset. 

# The run_with_snapshots method is an iterator that yields the
# current model time at the given interval. This means we can
# loop over the iterator saving the current model state.
for ii,t in enumerate(mod1.run_with_snapshots(run_time, snapshot_interval=output_interval)):
    print('Saving output at time: {}'.format(mod1.count))
    mod1.calc_energy_budget()
    ek[ii]=mod1.ek
    tak[ii]=mod1.tak
    fk[ii]=mod1.fk
    tkk[ii]=mod1.tkk
    vk[ii]=mod1.vk
    sk[ii]=mod1.sk
    saver.save()
saver.close()
# Out:
# starting from scratch
# spin up model
# ..spun up.. ..saving in steps..
# 99.99999999998154
# 70000
# Saving output at time: 20100
# Saving output at time: 20200
# Saving output at time: 20300
# Saving output at time: 20400
# Saving output at time: 20500
# Saving output at time: 20600
# Saving output at time: 20700
# Saving output at time: 20800
# Saving output at time: 20900
# Saving output at time: 21000
# Saving output at time: 21100
# Saving output at time: 21200
# Saving output at time: 21300
# Saving output at time: 21400
# Saving output at time: 21500
# Saving output at time: 21600
# Saving output at time: 21700
# Saving output at time: 21800
# Saving output at time: 21900
# Saving output at time: 22000
# Saving output at time: 22100
# Saving output at time: 22200
# Saving output at time: 22300
# Saving output at time: 22400
# Saving output at time: 22500
# Saving output at time: 22600
# Saving output at time: 22700
# Saving output at time: 22800
# Saving output at time: 22900
# Saving output at time: 23000
# Saving output at time: 23100
# Saving output at time: 23200
# Saving output at time: 23300
# Saving output at time: 23400
# Saving output at time: 23500
# Saving output at time: 23600
# Saving output at time: 23700
# Saving output at time: 23800
# Saving output at time: 23900
# Saving output at time: 24000
# Saving output at time: 24100
# Saving output at time: 24200
# Saving output at time: 24300
# Saving output at time: 24400
# Saving output at time: 24500
# Saving output at time: 24600
# Saving output at time: 24700
# Saving output at time: 24800
# Saving output at time: 24900
# Saving output at time: 25000
# Saving output at time: 25100
# Saving output at time: 25200
# Saving output at time: 25300
# Saving output at time: 25400
# Saving output at time: 25500
# Saving output at time: 25600
# Saving output at time: 25700
# Saving output at time: 25800
# Saving output at time: 25900
# Saving output at time: 26000
# Saving output at time: 26100
# Saving output at time: 26200
# Saving output at time: 26300
# Saving output at time: 26400
# Saving output at time: 26500
# Saving output at time: 26600
# Saving output at time: 26700
# Saving output at time: 26800
# Saving output at time: 26900
# Saving output at time: 27000
# Saving output at time: 27100
# Saving output at time: 27200
# Saving output at time: 27300
# Saving output at time: 27400
# Saving output at time: 27500
# Saving output at time: 27600
# Saving output at time: 27700
# Saving output at time: 27800
# Saving output at time: 27900
# Saving output at time: 28000
# Saving output at time: 28100
# Saving output at time: 28200
# Saving output at time: 28300
# Saving output at time: 28400
# Saving output at time: 28500
# Saving output at time: 28600
# Saving output at time: 28700
# Saving output at time: 28800
# Saving output at time: 28900
# Saving output at time: 29000
# Saving output at time: 29100
# Saving output at time: 29200
# Saving output at time: 29300
# Saving output at time: 29400
# Saving output at time: 29500
# Saving output at time: 29600
# Saving output at time: 29700
# Saving output at time: 29800
# Saving output at time: 29900
# Saving output at time: 30000
# Saving output at time: 30100
# Saving output at time: 30200
# Saving output at time: 30300
# Saving output at time: 30400
# Saving output at time: 30500
# Saving output at time: 30600
# Saving output at time: 30700
# Saving output at time: 30800
# Saving output at time: 30900
# Saving output at time: 31000
# Saving output at time: 31100
# Saving output at time: 31200
# Saving output at time: 31300
# Saving output at time: 31400
# Saving output at time: 31500
# Saving output at time: 31600
# Saving output at time: 31700
# Saving output at time: 31800
# Saving output at time: 31900
# Saving output at time: 32000
# Saving output at time: 32100
# Saving output at time: 32200
# Saving output at time: 32300
# Saving output at time: 32400
# Saving output at time: 32500
# Saving output at time: 32600
# Saving output at time: 32700
# Saving output at time: 32800
# Saving output at time: 32900
# Saving output at time: 33000
# Saving output at time: 33100
# Saving output at time: 33200
# Saving output at time: 33300
# Saving output at time: 33400
# Saving output at time: 33500
# Saving output at time: 33600
# Saving output at time: 33700
# Saving output at time: 33800
# Saving output at time: 33900
# Saving output at time: 34000
# Saving output at time: 34100
# Saving output at time: 34200
# Saving output at time: 34300
# Saving output at time: 34400
# Saving output at time: 34500
# Saving output at time: 34600
# Saving output at time: 34700
# Saving output at time: 34800
# Saving output at time: 34900
# Saving output at time: 35000
# Saving output at time: 35100
# Saving output at time: 35200
# Saving output at time: 35300
# Saving output at time: 35400
# Saving output at time: 35500
# Saving output at time: 35600
# Saving output at time: 35700
# Saving output at time: 35800
# Saving output at time: 35900
# Saving output at time: 36000
# Saving output at time: 36100
# Saving output at time: 36200
# Saving output at time: 36300
# Saving output at time: 36400
# Saving output at time: 36500
# Saving output at time: 36600
# Saving output at time: 36700
# Saving output at time: 36800
# Saving output at time: 36900
# Saving output at time: 37000
# Saving output at time: 37100
# Saving output at time: 37200
# Saving output at time: 37300
# Saving output at time: 37400
# Saving output at time: 37500
# Saving output at time: 37600
# Saving output at time: 37700
# Saving output at time: 37800
# Saving output at time: 37900
# Saving output at time: 38000
# Saving output at time: 38100
# Saving output at time: 38200
# Saving output at time: 38300
# Saving output at time: 38400
# Saving output at time: 38500
# Saving output at time: 38600
# Saving output at time: 38700
# Saving output at time: 38800
# Saving output at time: 38900
# Saving output at time: 39000
# Saving output at time: 39100
# Saving output at time: 39200
# Saving output at time: 39300
# Saving output at time: 39400
# Saving output at time: 39500
# Saving output at time: 39600
# Saving output at time: 39700
# Saving output at time: 39800
# Saving output at time: 39900
# Saving output at time: 40000
# Saving output at time: 40100
# Saving output at time: 40200
# Saving output at time: 40300
# Saving output at time: 40400
# Saving output at time: 40500
# Saving output at time: 40600
# Saving output at time: 40700
# Saving output at time: 40800
# Saving output at time: 40900
# Saving output at time: 41000
# Saving output at time: 41100
# Saving output at time: 41200
# Saving output at time: 41300
# Saving output at time: 41400
# Saving output at time: 41500
# Saving output at time: 41600
# Saving output at time: 41700
# Saving output at time: 41800
# Saving output at time: 41900
# Saving output at time: 42000
# Saving output at time: 42100
# Saving output at time: 42200
# Saving output at time: 42300
# Saving output at time: 42400
# Saving output at time: 42500
# Saving output at time: 42600
# Saving output at time: 42700
# Saving output at time: 42800
# Saving output at time: 42900
# Saving output at time: 43000
# Saving output at time: 43100
# Saving output at time: 43200
# Saving output at time: 43300
# Saving output at time: 43400
# Saving output at time: 43500
# Saving output at time: 43600
# Saving output at time: 43700
# Saving output at time: 43800
# Saving output at time: 43900
# Saving output at time: 44000
# Saving output at time: 44100
# Saving output at time: 44200
# Saving output at time: 44300
# Saving output at time: 44400
# Saving output at time: 44500
# Saving output at time: 44600
# Saving output at time: 44700
# Saving output at time: 44800
# Saving output at time: 44900
# Saving output at time: 45000
# Saving output at time: 45100
# Saving output at time: 45200
# Saving output at time: 45300
# Saving output at time: 45400
# Saving output at time: 45500
# Saving output at time: 45600
# Saving output at time: 45700
# Saving output at time: 45800
# Saving output at time: 45900
# Saving output at time: 46000
# Saving output at time: 46100
# Saving output at time: 46200
# Saving output at time: 46300
# Saving output at time: 46400
# Saving output at time: 46500
# Saving output at time: 46600
# Saving output at time: 46700
# Saving output at time: 46800
# Saving output at time: 46900
# Saving output at time: 47000
# Saving output at time: 47100
# Saving output at time: 47200
# Saving output at time: 47300
# Saving output at time: 47400
# Saving output at time: 47500
# Saving output at time: 47600
# Saving output at time: 47700
# Saving output at time: 47800
# Saving output at time: 47900
# Saving output at time: 48000
# Saving output at time: 48100
# Saving output at time: 48200
# Saving output at time: 48300
# Saving output at time: 48400
# Saving output at time: 48500
# Saving output at time: 48600
# Saving output at time: 48700
# Saving output at time: 48800
# Saving output at time: 48900
# Saving output at time: 49000
# Saving output at time: 49100
# Saving output at time: 49200
# Saving output at time: 49300
# Saving output at time: 49400
# Saving output at time: 49500
# Saving output at time: 49600
# Saving output at time: 49700
# Saving output at time: 49800
# Saving output at time: 49900
# Saving output at time: 50000
# Saving output at time: 50100
# Saving output at time: 50200
# Saving output at time: 50300
# Saving output at time: 50400
# Saving output at time: 50500
# Saving output at time: 50600
# Saving output at time: 50700
# Saving output at time: 50800
# Saving output at time: 50900
# Saving output at time: 51000
# Saving output at time: 51100
# Saving output at time: 51200
# Saving output at time: 51300
# Saving output at time: 51400
# Saving output at time: 51500
# Saving output at time: 51600
# Saving output at time: 51700
# Saving output at time: 51800
# Saving output at time: 51900
# Saving output at time: 52000
# Saving output at time: 52100
# Saving output at time: 52200
# Saving output at time: 52300
# Saving output at time: 52400
# Saving output at time: 52500
# Saving output at time: 52600
# Saving output at time: 52700
# Saving output at time: 52800
# Saving output at time: 52900
# Saving output at time: 53000
# Saving output at time: 53100
# Saving output at time: 53200
# Saving output at time: 53300
# Saving output at time: 53400
# Saving output at time: 53500
# Saving output at time: 53600
# Saving output at time: 53700
# Saving output at time: 53800
# Saving output at time: 53900
# Saving output at time: 54000
# Saving output at time: 54100
# Saving output at time: 54200
# Saving output at time: 54300
# Saving output at time: 54400
# Saving output at time: 54500
# Saving output at time: 54600
# Saving output at time: 54700
# Saving output at time: 54800
# Saving output at time: 54900
# Saving output at time: 55000
# Saving output at time: 55100
# Saving output at time: 55200
# Saving output at time: 55300
# Saving output at time: 55400
# Saving output at time: 55500
# Saving output at time: 55600
# Saving output at time: 55700
# Saving output at time: 55800
# Saving output at time: 55900
# Saving output at time: 56000
# Saving output at time: 56100
# Saving output at time: 56200
# Saving output at time: 56300
# Saving output at time: 56400
# Saving output at time: 56500
# Saving output at time: 56600
# Saving output at time: 56700
# Saving output at time: 56800
# Saving output at time: 56900
# Saving output at time: 57000
# Saving output at time: 57100
# Saving output at time: 57200
# Saving output at time: 57300
# Saving output at time: 57400
# Saving output at time: 57500
# Saving output at time: 57600
# Saving output at time: 57700
# Saving output at time: 57800
# Saving output at time: 57900
# Saving output at time: 58000
# Saving output at time: 58100
# Saving output at time: 58200
# Saving output at time: 58300
# Saving output at time: 58400
# Saving output at time: 58500
# Saving output at time: 58600
# Saving output at time: 58700
# Saving output at time: 58800
# Saving output at time: 58900
# Saving output at time: 59000
# Saving output at time: 59100
# Saving output at time: 59200
# Saving output at time: 59300
# Saving output at time: 59400
# Saving output at time: 59500
# Saving output at time: 59600
# Saving output at time: 59700
# Saving output at time: 59800
# Saving output at time: 59900
# Saving output at time: 60000
# Saving output at time: 60100
# Saving output at time: 60200
# Saving output at time: 60300
# Saving output at time: 60400
# Saving output at time: 60500
# Saving output at time: 60600
# Saving output at time: 60700
# Saving output at time: 60800
# Saving output at time: 60900
# Saving output at time: 61000
# Saving output at time: 61100
# Saving output at time: 61200
# Saving output at time: 61300
# Saving output at time: 61400
# Saving output at time: 61500
# Saving output at time: 61600
# Saving output at time: 61700
# Saving output at time: 61800
# Saving output at time: 61900
# Saving output at time: 62000
# Saving output at time: 62100
# Saving output at time: 62200
# Saving output at time: 62300
# Saving output at time: 62400
# Saving output at time: 62500
# Saving output at time: 62600
# Saving output at time: 62700
# Saving output at time: 62800
# Saving output at time: 62900
# Saving output at time: 63000
# Saving output at time: 63100
# Saving output at time: 63200
# Saving output at time: 63300
# Saving output at time: 63400
# Saving output at time: 63500
# Saving output at time: 63600
# Saving output at time: 63700
# Saving output at time: 63800
# Saving output at time: 63900
# Saving output at time: 64000
# Saving output at time: 64100
# Saving output at time: 64200
# Saving output at time: 64300
# Saving output at time: 64400
# Saving output at time: 64500
# Saving output at time: 64600
# Saving output at time: 64700
# Saving output at time: 64800
# Saving output at time: 64900
# Saving output at time: 65000
# Saving output at time: 65100
# Saving output at time: 65200
# Saving output at time: 65300
# Saving output at time: 65400
# Saving output at time: 65500
# Saving output at time: 65600
# Saving output at time: 65700
# Saving output at time: 65800
# Saving output at time: 65900
# Saving output at time: 66000
# Saving output at time: 66100
# Saving output at time: 66200
# Saving output at time: 66300
# Saving output at time: 66400
# Saving output at time: 66500
# Saving output at time: 66600
# Saving output at time: 66700
# Saving output at time: 66800
# Saving output at time: 66900
# Saving output at time: 67000
# Saving output at time: 67100
# Saving output at time: 67200
# Saving output at time: 67300
# Saving output at time: 67400
# Saving output at time: 67500
# Saving output at time: 67600
# Saving output at time: 67700
# Saving output at time: 67800
# Saving output at time: 67900
# Saving output at time: 68000
# Saving output at time: 68100
# Saving output at time: 68200
# Saving output at time: 68300
# Saving output at time: 68400
# Saving output at time: 68500
# Saving output at time: 68600
# Saving output at time: 68700
# Saving output at time: 68800
# Saving output at time: 68900
# Saving output at time: 69000
# Saving output at time: 69100
# Saving output at time: 69200
# Saving output at time: 69300
# Saving output at time: 69400
# Saving output at time: 69500
# Saving output at time: 69600
# Saving output at time: 69700
# Saving output at time: 69800
# Saving output at time: 69900
# Saving output at time: 70000
# Saving output at time: 70100
# Saving output at time: 70200
# Saving output at time: 70300
# Saving output at time: 70400
# Saving output at time: 70500
# Saving output at time: 70600
# Saving output at time: 70700
# Saving output at time: 70800
# Saving output at time: 70900
# Saving output at time: 71000
# Saving output at time: 71100
# Saving output at time: 71200
# Saving output at time: 71300
# Saving output at time: 71400
# Saving output at time: 71500
# Saving output at time: 71600
# Saving output at time: 71700
# Saving output at time: 71800
# Saving output at time: 71900
# Saving output at time: 72000
# Saving output at time: 72100
# Saving output at time: 72200
# Saving output at time: 72300
# Saving output at time: 72400
# Saving output at time: 72500
# Saving output at time: 72600
# Saving output at time: 72700
# Saving output at time: 72800
# Saving output at time: 72900
# Saving output at time: 73000
# Saving output at time: 73100
# Saving output at time: 73200
# Saving output at time: 73300
# Saving output at time: 73400
# Saving output at time: 73500
# Saving output at time: 73600
# Saving output at time: 73700
# Saving output at time: 73800
# Saving output at time: 73900
# Saving output at time: 74000
# Saving output at time: 74100
# Saving output at time: 74200
# Saving output at time: 74300
# Saving output at time: 74400
# Saving output at time: 74500
# Saving output at time: 74600
# Saving output at time: 74700
# Saving output at time: 74800
# Saving output at time: 74900
# Saving output at time: 75000
# Saving output at time: 75100
# Saving output at time: 75200
# Saving output at time: 75300
# Saving output at time: 75400
# Saving output at time: 75500
# Saving output at time: 75600
# Saving output at time: 75700
# Saving output at time: 75800
# Saving output at time: 75900
# Saving output at time: 76000
# Saving output at time: 76100
# Saving output at time: 76200
# Saving output at time: 76300
# Saving output at time: 76400
# Saving output at time: 76500
# Saving output at time: 76600
# Saving output at time: 76700
# Saving output at time: 76800
# Saving output at time: 76900
# Saving output at time: 77000
# Saving output at time: 77100
# Saving output at time: 77200
# Saving output at time: 77300
# Saving output at time: 77400
# Saving output at time: 77500
# Saving output at time: 77600
# Saving output at time: 77700
# Saving output at time: 77800
# Saving output at time: 77900
# Saving output at time: 78000
# Saving output at time: 78100
# Saving output at time: 78200
# Saving output at time: 78300
# Saving output at time: 78400
# Saving output at time: 78500
# Saving output at time: 78600
# Saving output at time: 78700
# Saving output at time: 78800
# Saving output at time: 78900
# Saving output at time: 79000
# Saving output at time: 79100
# Saving output at time: 79200
# Saving output at time: 79300
# Saving output at time: 79400
# Saving output at time: 79500
# Saving output at time: 79600
# Saving output at time: 79700
# Saving output at time: 79800
# Saving output at time: 79900
# Saving output at time: 80000
# Saving output at time: 80100
# Saving output at time: 80200
# Saving output at time: 80300
# Saving output at time: 80400
# Saving output at time: 80500
# Saving output at time: 80600
# Saving output at time: 80700
# Saving output at time: 80800
# Saving output at time: 80900
# Saving output at time: 81000
# Saving output at time: 81100
# Saving output at time: 81200
# Saving output at time: 81300
# Saving output at time: 81400
# Saving output at time: 81500
# Saving output at time: 81600
# Saving output at time: 81700
# Saving output at time: 81800
# Saving output at time: 81900
# Saving output at time: 82000
# Saving output at time: 82100
# Saving output at time: 82200
# Saving output at time: 82300
# Saving output at time: 82400
# Saving output at time: 82500
# Saving output at time: 82600
# Saving output at time: 82700
# Saving output at time: 82800
# Saving output at time: 82900
# Saving output at time: 83000
# Saving output at time: 83100
# Saving output at time: 83200
# Saving output at time: 83300
# Saving output at time: 83400
# Saving output at time: 83500
# Saving output at time: 83600
# Saving output at time: 83700
# Saving output at time: 83800
# Saving output at time: 83900
# Saving output at time: 84000
# Saving output at time: 84100
# Saving output at time: 84200
# Saving output at time: 84300
# Saving output at time: 84400
# Saving output at time: 84500
# Saving output at time: 84600
# Saving output at time: 84700
# Saving output at time: 84800
# Saving output at time: 84900
# Saving output at time: 85000
# Saving output at time: 85100
# Saving output at time: 85200
# Saving output at time: 85300
# Saving output at time: 85400
# Saving output at time: 85500
# Saving output at time: 85600
# Saving output at time: 85700
# Saving output at time: 85800
# Saving output at time: 85900
# Saving output at time: 86000
# Saving output at time: 86100
# Saving output at time: 86200
# Saving output at time: 86300
# Saving output at time: 86400
# Saving output at time: 86500
# Saving output at time: 86600
# Saving output at time: 86700
# Saving output at time: 86800
# Saving output at time: 86900
# Saving output at time: 87000
# Saving output at time: 87100
# Saving output at time: 87200
# Saving output at time: 87300
# Saving output at time: 87400
# Saving output at time: 87500
# Saving output at time: 87600
# Saving output at time: 87700
# Saving output at time: 87800
# Saving output at time: 87900
# Saving output at time: 88000
# Saving output at time: 88100
# Saving output at time: 88200
# Saving output at time: 88300
# Saving output at time: 88400
# Saving output at time: 88500
# Saving output at time: 88600
# Saving output at time: 88700
# Saving output at time: 88800
# Saving output at time: 88900
# Saving output at time: 89000
# Saving output at time: 89100
# Saving output at time: 89200
# Saving output at time: 89300
# Saving output at time: 89400
# Saving output at time: 89500
# Saving output at time: 89600
# Saving output at time: 89700
# Saving output at time: 89800
# Saving output at time: 89900
# Saving output at time: 90000

# %% [markdown]
# ## Plot Current PV Values:

# %%
#how many time steps to save: 
mod1 = QG2D_Model(N1,N2,dt,Lx,Ly,topo=True)
mod1.random_init()
TS = 40000  #integrate without saving. 
for ii in range(0,TS):
    mod1.integrate()
    mod1.calc_energy_budget()
# Out:
# starting from scratch

# %%
pv1,pv2 = mod1.q_sp2re()
plt.figure(figsize=(12,4))
ax = plt.subplot(1, 2, 1)
plt.contourf(mod1.x, mod1.y, pv1,30,cmap = plt.cm.coolwarm, vmin=-50,vmax=50)
cs = plt.colorbar()
cs.set_label("PV$_1$")

ax = plt.subplot(1, 2, 2)
plt.contourf(mod1.x, mod1.y, pv2,30,cmap = plt.cm.coolwarm, vmin=-30,vmax=30)
cs = plt.colorbar()
cs.set_label("PV$_2$")

plt.show()

plt.figure(figsize=(12,4))
ax = plt.subplot(1, 2, 1)
plt.semilogy(nKs[1:], nek[1:] )
plt.xlim([0,6])

plt.subplot(1, 2, 2)
plt.plot( nKs, nsk )
plt.plot(  nKs, ntak)
plt.plot(  nKs, ntkk)
plt.plot(  nKs, nfk )
plt.plot(  nKs, nvk)
plt.xlim([0,2])
plt.legend(["sk", "tak", "tkk", "fk", "vk"], loc = "upper right",fontsize=14)
plt.show()

# %%
ek = np.mean(ek, axis = 0)
ek = np.reshape(ek, (mod1.N2 * (mod1.N//2 + 1) ))

sk = np.mean(sk, axis = 0)
sk = np.reshape(sk, (mod1.N2 * (mod1.N//2 + 1) ))

tak = np.mean(tak, axis = 0)
tak = np.reshape(tak, (mod1.N2 * (mod1.N//2 + 1) ))

tkk = np.mean(tkk, axis = 0)
tkk = np.reshape(tkk, (mod1.N2 * (mod1.N//2 + 1) ))

fk = np.mean(fk, axis = 0)
fk = np.reshape(fk, (mod1.N2 * (mod1.N//2 + 1) ))

vk = np.mean(vk, axis = 0)
vk = np.reshape(vk, (mod1.N2 * (mod1.N//2 + 1) ))

Ks = np.reshape( mod1.Ks, (mod1.N2 * (mod1.N//2 + 1) ))
inds = Ks.argsort()
Ks.sort()
ek = ek[inds] 
sk = sk[inds] 
tak = tak[inds] 
tkk = tkk[inds] 
fk = fk[inds] 
vk = vk[inds] 

#Sum over duplicates. There must be a better way...
nKs = np.unique( Ks )
nek = np.zeros( len(nKs) )
nsk = np.zeros( len(nKs) )
ntak = np.zeros( len(nKs) )
ntkk = np.zeros( len(nKs) )
nfk = np.zeros( len(nKs) )
nvk = np.zeros( len(nKs) )
for i in range( len(nKs) ):
    nek[i] = sum(ek[np.where( Ks == nKs[i])])
    nsk[i] = sum(sk[np.where( Ks == nKs[i])])
    ntak[i] = sum(tak[np.where( Ks == nKs[i])])
    ntkk[i] = sum(tkk[np.where( Ks == nKs[i])])
    nfk[i] = sum(fk[np.where( Ks == nKs[i])])
    nvk[i] = sum(vk[np.where( Ks == nKs[i])])
